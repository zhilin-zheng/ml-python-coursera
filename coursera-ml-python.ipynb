# %% [markdown]
# <a href="https://www.bigdatauniversity.com"><img src="https://ibm.box.com/shared/static/cw2c7r3o20w9zn8gkecaeyjhgw3xdgbj.png" width="400" align="center"></a>
#
# <h1 align="center"><font size="5">Classification with Python</font></h1>

# %% [markdown]
# In this notebook we try to practice all the classification algorithms that we learned in this course.
#
# We load a dataset using Pandas library, and apply the following algorithms, and find the best one for this specific dataset by accuracy evaluation methods.
#
# Lets first load required libraries:

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
import pandas as pd
import numpy as np
import matplotlib.ticker as ticker
from sklearn import preprocessing
# %matplotlib inline

# %% [markdown]
# ### About dataset

# %% [markdown]
# This dataset is about past loans. The __Loan_train.csv__ data set includes details of 346 customers whose loan are already paid off or defaulted. It includes following fields:
#
# | Field          | Description                                                                           |
# |----------------|---------------------------------------------------------------------------------------|
# | Loan_status    | Whether a loan is paid off on in collection                                           |
# | Principal      | Basic principal loan amount at the                                                    |
# | Terms          | Origination terms which can be weekly (7 days), biweekly, and monthly payoff schedule |
# | Effective_date | When the loan got originated and took effects                                         |
# | Due_date       | Since it’s one-time payoff schedule, each loan has one single due date                |
# | Age            | Age of applicant                                                                      |
# | Education      | Education of applicant                                                                |
# | Gender         | The gender of applicant                                                               |

# %% [markdown]
# Lets download the dataset

# %%
# !wget -O loan_train.csv https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0101ENv3/labs/loan_train.csv
# Out:
# --2021-03-01 20:48:54--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0101ENv3/labs/loan_train.csv
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.196
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23101 (23K) [text/csv]
# Saving to: ‘loan_train.csv’
#
# loan_train.csv      100%[===================>]  22.56K  --.-KB/s    in 0.001s
#
# 2021-03-01 20:48:54 (19.4 MB/s) - ‘loan_train.csv’ saved [23101/23101]

# %% [markdown]
# ### Load Data From CSV File

# %%
df = pd.read_csv('loan_train.csv')
df.tail()
# Out:
#      Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 341         394           394  COLLECTION        800     15      9/11/2016
# 342         395           395  COLLECTION       1000     30      9/11/2016
# 343         397           397  COLLECTION        800     15      9/12/2016
# 344         398           398  COLLECTION       1000     30      9/12/2016
# 345         399           399  COLLECTION       1000     30      9/12/2016
#
#        due_date  age             education Gender
# 341   9/25/2016   32  High School or Below   male
# 342  10/10/2016   25  High School or Below   male
# 343   9/26/2016   39               college   male
# 344  11/10/2016   28               college   male
# 345  10/11/2016   26               college   male

# %%
df.shape
# Out:
# (346, 10)

# %% [markdown]
# ### Convert to date time object

# %%
df['due_date'] = pd.to_datetime(df['due_date'])
df['effective_date'] = pd.to_datetime(df['effective_date'])
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           0             0     PAIDOFF       1000     30     2016-09-08
# 1           2             2     PAIDOFF       1000     30     2016-09-08
# 2           3             3     PAIDOFF       1000     15     2016-09-08
# 3           4             4     PAIDOFF       1000     30     2016-09-09
# 4           6             6     PAIDOFF       1000     30     2016-09-09
#
#     due_date  age             education  Gender
# 0 2016-10-07   45  High School or Below    male
# 1 2016-10-07   33              Bechalor  female
# 2 2016-09-22   27               college    male
# 3 2016-10-08   28               college  female
# 4 2016-10-08   29               college    male

# %% [markdown]
# # Data visualization and pre-processing

# %% [markdown]
# Let’s see how many of each class is in our data set

# %%
df['loan_status'].value_counts()
# Out:
# PAIDOFF       260
# COLLECTION     86
# Name: loan_status, dtype: int64

# %% [markdown]
# 260 people have paid off the loan on time while 86 have gone into collection

# %% [markdown]
# Lets plot some columns to underestand data better:

# %%
# notice: installing seaborn might takes a few minutes
# !conda install -c anaconda seaborn -y
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python-3.7-main
#
#   added / updated specs:
#     - seaborn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |             main           3 KB  anaconda
#     _py-xgboost-mutex-2.0      |            cpu_0           9 KB  anaconda
#     _pytorch_select-0.1        |            cpu_0           2 KB  anaconda
#     absl-py-0.10.0             |           py37_0         169 KB  anaconda
#     aiohttp-3.6.3              |   py37h7b6447c_0         626 KB  anaconda
# ...

# %%
import seaborn as sns

bins = np.linspace(df.Principal.min(), df.Principal.max(), 10)
g = sns.FacetGrid(df, col="Gender", hue="loan_status", palette="Set1", col_wrap=2)
g.map(plt.hist, 'Principal', bins=bins, ec="k")

g.axes[-1].legend()
plt.show()

# %%
bins = np.linspace(df.age.min(), df.age.max(), 10)
g = sns.FacetGrid(df, col="Gender", hue="loan_status", palette="Set1", col_wrap=2)
g.map(plt.hist, 'age', bins=bins, ec="k")

g.axes[-1].legend()
plt.show()

# %% [markdown]
# # Pre-processing:  Feature selection/extraction

# %% [markdown]
# ### Lets look at the day of the week people get the loan

# %%
df['dayofweek'] = df['effective_date'].dt.dayofweek
bins = np.linspace(df.dayofweek.min(), df.dayofweek.max(), 10)
g = sns.FacetGrid(df, col="Gender", hue="loan_status", palette="Set1", col_wrap=2)
g.map(plt.hist, 'dayofweek', bins=bins, ec="k")
g.axes[-1].legend()
plt.show()

# %% [markdown]
# We see that people who get the loan at the end of the week dont pay it off, so lets use Feature binarization to set a threshold values less then day 4

# %%
df['weekend'] = df['dayofweek'].apply(lambda x: 1 if (x>3)  else 0)
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           0             0     PAIDOFF       1000     30     2016-09-08
# 1           2             2     PAIDOFF       1000     30     2016-09-08
# 2           3             3     PAIDOFF       1000     15     2016-09-08
# 3           4             4     PAIDOFF       1000     30     2016-09-09
# 4           6             6     PAIDOFF       1000     30     2016-09-09
#
#     due_date  age             education  Gender  dayofweek  weekend
# 0 2016-10-07   45  High School or Below    male          3        0
# 1 2016-10-07   33              Bechalor  female          3        0
# 2 2016-09-22   27               college    male          3        0
# 3 2016-10-08   28               college  female          4        1
# 4 2016-10-08   29               college    male          4        1

# %% [markdown]
# ## Convert Categorical features to numerical values

# %% [markdown]
# Lets look at gender:

# %%
df.groupby(['Gender'])['loan_status'].value_counts(normalize=True)
# Out:
# Gender  loan_status
# female  PAIDOFF        0.865385
#         COLLECTION     0.134615
# male    PAIDOFF        0.731293
#         COLLECTION     0.268707
# Name: loan_status, dtype: float64

# %% [markdown]
# 86 % of female pay there loans while only 73 % of males pay there loan

# %% [markdown]
# Lets convert male to 0 and female to 1:

# %%
df['Gender'].replace(to_replace=['male','female'], value=[0,1],inplace=True)
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           0             0     PAIDOFF       1000     30     2016-09-08
# 1           2             2     PAIDOFF       1000     30     2016-09-08
# 2           3             3     PAIDOFF       1000     15     2016-09-08
# 3           4             4     PAIDOFF       1000     30     2016-09-09
# 4           6             6     PAIDOFF       1000     30     2016-09-09
#
#     due_date  age             education  Gender  dayofweek  weekend
# 0 2016-10-07   45  High School or Below       0          3        0
# 1 2016-10-07   33              Bechalor       1          3        0
# 2 2016-09-22   27               college       0          3        0
# 3 2016-10-08   28               college       1          4        1
# 4 2016-10-08   29               college       0          4        1

# %% [markdown]
# ## One Hot Encoding
# #### How about education?

# %%
df.groupby(['education'])['loan_status'].value_counts(normalize=True)
# Out:
# education             loan_status
# Bechalor              PAIDOFF        0.750000
#                       COLLECTION     0.250000
# High School or Below  PAIDOFF        0.741722
#                       COLLECTION     0.258278
# Master or Above       COLLECTION     0.500000
#                       PAIDOFF        0.500000
# college               PAIDOFF        0.765101
#                       COLLECTION     0.234899
# Name: loan_status, dtype: float64

# %% [markdown]
# #### Feature befor One Hot Encoding

# %%
df[['Principal','terms','age','Gender','education']].head()
# Out:
#    Principal  terms  age  Gender             education
# 0       1000     30   45       0  High School or Below
# 1       1000     30   33       1              Bechalor
# 2       1000     15   27       0               college
# 3       1000     30   28       1               college
# 4       1000     30   29       0               college

# %% [markdown]
# #### Use one hot encoding technique to conver categorical varables to binary variables and append them to the feature Data Frame

# %%
Feature = df[['Principal','terms','age','Gender','weekend']]
Feature = pd.concat([Feature,pd.get_dummies(df['education'])], axis=1)
Feature.drop(['Master or Above'], axis = 1,inplace=True)
Feature.head()
# Out:
#    Principal  terms  age  Gender  weekend  Bechalor  High School or Below  \
# 0       1000     30   45       0        0         0                     1
# 1       1000     30   33       1        0         1                     0
# 2       1000     15   27       0        0         0                     0
# 3       1000     30   28       1        1         0                     0
# 4       1000     30   29       0        1         0                     0
#
#    college
# 0        0
# 1        0
# 2        1
# 3        1
# 4        1

# %% [markdown]
# ### Feature selection

# %% [markdown]
# Lets defind feature sets, X:

# %%
X = Feature
X[0:5]
# Out:
#    Principal  terms  age  Gender  weekend  Bechalor  High School or Below  \
# 0       1000     30   45       0        0         0                     1
# 1       1000     30   33       1        0         1                     0
# 2       1000     15   27       0        0         0                     0
# 3       1000     30   28       1        1         0                     0
# 4       1000     30   29       0        1         0                     0
#
#    college
# 0        0
# 1        0
# 2        1
# 3        1
# 4        1

# %% [markdown]
# What are our lables?

# %%
y = df['loan_status'].values
y[0:5]
# Out:
# array(['PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF'],
#       dtype=object)

# %% [markdown]
# ## Normalize Data

# %% [markdown]
# Data Standardization give data zero mean and unit variance (technically should be done after train test split )

# %%
X= preprocessing.StandardScaler().fit(X).transform(X)
X[0:5]
# Out:
# array([[ 0.51578458,  0.92071769,  2.33152555, -0.42056004, -1.20577805,
#         -0.38170062,  1.13639374, -0.86968108],
#        [ 0.51578458,  0.92071769,  0.34170148,  2.37778177, -1.20577805,
#          2.61985426, -0.87997669, -0.86968108],
#        [ 0.51578458, -0.95911111, -0.65321055, -0.42056004, -1.20577805,
#         -0.38170062, -0.87997669,  1.14984679],
#        [ 0.51578458,  0.92071769, -0.48739188,  2.37778177,  0.82934003,
#         -0.38170062, -0.87997669,  1.14984679],
#        [ 0.51578458,  0.92071769, -0.3215732 , -0.42056004,  0.82934003,
#         -0.38170062, -0.87997669,  1.14984679]])

# %% [markdown]
# # Classification

# %% [markdown]
# Now, it is your turn, use the training set to build an accurate model. Then use the test set to report the accuracy of the model
# You should use the following algorithm:
# - K Nearest Neighbor(KNN)
# - Decision Tree
# - Support Vector Machine
# - Logistic Regression
#
#
#
# __ Notice:__
# - You can go above and change the pre-processing, feature selection, feature-extraction, and so on, to make a better model.
# - You should use either scikit-learn, Scipy or Numpy libraries for developing the classification algorithms.
# - You should include the code of the algorithm in the following cells.

# %% [markdown]
# # K Nearest Neighbor(KNN)
# Notice: You should find the best k to build the model with the best accuracy.
# **warning:** You should not use the __loan_test.csv__ for finding the best k, however, you can split your train_loan.csv into train and test to find the best __k__.

# %%
# convert categorical targets into numbers
print(df['loan_status'].value_counts())
df['loan_status_num'] = df['loan_status'].apply(lambda x: 1 if (x=='PAIDOFF')  else -1)
df.head()
y_num = np.asarray(df['loan_status_num'])
y_num [-5:]
# Out:
# PAIDOFF       260
# COLLECTION     86
# Name: loan_status, dtype: int64
# array([-1, -1, -1, -1, -1])

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score


# find the best k
Ks = 20
mean_f1 = np.zeros((Ks))
std_f1 = np.zeros((Ks))

n_fold = 5
for n in range(1, Ks+1):
    # cross validation
    scores = cross_val_score(KNeighborsClassifier(n_neighbors=n), X, y_num,
                         scoring="f1", cv=n_fold)
    mean_f1[n-1] = scores.mean()
    std_f1[n-1] = scores.std()

for a, b, c in zip(range(1, Ks+1), mean_f1, std_f1):
    print("K={}, mean f1: {}, f1 std: {}".format(a, b, c))
# Out:
# K=1, mean f1: 0.774602914761809, f1 std: 0.10998524822820259
# K=2, mean f1: 0.720852203992312, f1 std: 0.15841551389578498
# K=3, mean f1: 0.7978175970965518, f1 std: 0.09922895805064005
# K=4, mean f1: 0.7698361442807821, f1 std: 0.14770668335614917
# K=5, mean f1: 0.8150754921006726, f1 std: 0.06790255771397133
# K=6, mean f1: 0.779264938748881, f1 std: 0.14077196760700192
# K=7, mean f1: 0.8132215109846689, f1 std: 0.09132800669470592
# K=8, mean f1: 0.7546761988205468, f1 std: 0.1602028827224706
# K=9, mean f1: 0.7840160261420394, f1 std: 0.11832843545822926
# K=10, mean f1: 0.7394872327506312, f1 std: 0.1707204140543327
# K=11, mean f1: 0.7744341245270038, f1 std: 0.13169408417999154
# K=12, mean f1: 0.7164018000515747, f1 std: 0.19876715836959652
# K=13, mean f1: 0.7650023165916366, f1 std: 0.13190795089209845
# K=14, mean f1: 0.7425127143843335, f1 std: 0.17463144991348628
# K=15, mean f1: 0.7745711903777247, f1 std: 0.12555817767795963
# ...

# %%
# plot accuracy
plt.plot(range(1, Ks+1), acc, 'g')
plt.fill_between(range(1, Ks+1), mean_f1 - 1 * std_f1, mean_f1 + 1 * std_f1, alpha=0.10)
plt.fill_between(range(1, Ks+1), mean_f1 - 3 * std_f1, mean_f1 + 3 * std_f1, alpha=0.10, color="green")
plt.legend(('F1 ', '+/- 1xstd','+/- 3xstd'))
plt.ylabel('F1 ')
plt.xlabel('Number of Neighbors (K)')
plt.xticks(np.arange(min(range(1, Ks+1)), max(range(1, Ks+1))+1, 1.0))
plt.show()

# %%
# print out K with the max accuracy
print("The best accuracy was", mean_f1.max(), "with k =", mean_f1.argmax() + 1)
# Out:
# The best accuracy was 0.8150754921006726 with k = 5

# %% [markdown]
#  ## Other hyperparameters than n_neighbors could also impact results, for instance, *leaf_size* and *p*
#  let's try grid search to find the best hyperparameters

# %%
from sklearn.model_selection import GridSearchCV

max_leaf_size = 50
Ks = 20
n_fold = 5
param_grid = [
    {'n_neighbors': range(1, Ks+1), 'leaf_size': range(10, max_leaf_size+1, 5), 'p': [1, 2]}
  ]
clsf_knn = KNeighborsClassifier()
grid_search_knn = GridSearchCV(clsf_knn, param_grid, cv=n_fold,
                           scoring='f1',
                           return_train_score=True)

grid_search_knn.fit(X, y_num)
grid_search_knn.best_params_
# Out:
# {'leaf_size': 10, 'n_neighbors': 7, 'p': 2}

# %%
# print out all params combination and its accuracy
cvres = grid_search_knn.cv_results_
print("max f1: ", cvres["mean_test_score"].max())
print("\n")
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(mean_score, params)
# Out:
# max f1:  0.8207349115961897
#
#
# 0.7731557935637143 {'leaf_size': 10, 'n_neighbors': 1, 'p': 1}
# 0.7760841852361005 {'leaf_size': 10, 'n_neighbors': 1, 'p': 2}
# 0.7048906356801095 {'leaf_size': 10, 'n_neighbors': 2, 'p': 1}
# 0.7224311513607331 {'leaf_size': 10, 'n_neighbors': 2, 'p': 2}
# 0.7850778878789584 {'leaf_size': 10, 'n_neighbors': 3, 'p': 1}
# 0.7921392913877302 {'leaf_size': 10, 'n_neighbors': 3, 'p': 2}
# 0.7623289592245772 {'leaf_size': 10, 'n_neighbors': 4, 'p': 1}
# 0.7698361442807821 {'leaf_size': 10, 'n_neighbors': 4, 'p': 2}
# 0.8120305291267179 {'leaf_size': 10, 'n_neighbors': 5, 'p': 1}
# 0.8196263848328929 {'leaf_size': 10, 'n_neighbors': 5, 'p': 2}
# 0.7738778901773402 {'leaf_size': 10, 'n_neighbors': 6, 'p': 1}
# 0.778661620498504 {'leaf_size': 10, 'n_neighbors': 6, 'p': 2}
# 0.8105317172240948 {'leaf_size': 10, 'n_neighbors': 7, 'p': 1}
# 0.8207349115961897 {'leaf_size': 10, 'n_neighbors': 7, 'p': 2}
# ...

# %% [markdown]
# # Decision Tree

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier


criterion = ['gini', 'entropy']
max_depth = [2,4,6,8,10,12]

n_fold = 5
param_grid_dt = [
    {'criterion': criterion, 'max_depth': max_depth}
  ]
clsf_dt = DecisionTreeClassifier()
grid_search_dt = GridSearchCV(clsf_dt, param_grid_dt, cv=n_fold,
                           scoring='f1',
                           return_train_score=True)

grid_search_dt.fit(X, y_num)
grid_search_dt.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 10}

# %%
# print out all params combination and its accuracy

cvres_dt = grid_search_dt.cv_results_
print("max f1: ", cvres_dt["mean_test_score"].max())
print("\n")
for mean_score, params in zip(cvres_dt["mean_test_score"], cvres_dt["params"]):
    print(mean_score, params)
# Out:
# max f1:  0.7859392149680753
#
#
# 0.6500575240387153 {'criterion': 'gini', 'max_depth': 2}
# 0.637481070014602 {'criterion': 'gini', 'max_depth': 4}
# 0.7033343553137742 {'criterion': 'gini', 'max_depth': 6}
# 0.6910255420510182 {'criterion': 'gini', 'max_depth': 8}
# 0.719094304388422 {'criterion': 'gini', 'max_depth': 10}
# 0.7501975957148371 {'criterion': 'gini', 'max_depth': 12}
# 0.6500575240387153 {'criterion': 'entropy', 'max_depth': 2}
# 0.639381896460883 {'criterion': 'entropy', 'max_depth': 4}
# 0.6824033744033744 {'criterion': 'entropy', 'max_depth': 6}
# 0.6837249664364788 {'criterion': 'entropy', 'max_depth': 8}
# 0.7859392149680753 {'criterion': 'entropy', 'max_depth': 10}
# 0.7713013241452982 {'criterion': 'entropy', 'max_depth': 12}

# %% [markdown]
# ## viz tree

# %%
# !pip install pydotplus

# %%
from  io import StringIO
import pydotplus
import matplotlib.image as mpimg
from sklearn import tree
# %matplotlib inline 


loanTree = grid_search_dt.best_estimator_
dot_data = StringIO()
filename = "loantree.png"
featureNames = Feature.columns[0:8]
out=tree.export_graphviz(loanTree,feature_names=featureNames, out_file=dot_data, class_names= np.unique(y), filled=True,  special_characters=True,rotate=False)  
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png(filename)
img = mpimg.imread(filename)
plt.figure(figsize=(100, 200))
plt.imshow(img,interpolation='nearest')

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn import svm
from sklearn.model_selection import GridSearchCV


n_fold = 5
param_grid_svc = [
    {'C': [0.1, 1, 10],  
    'kernel': ['linear', 'poly', 'rbf', 'sigmoid']}
  ]
clsf_svc = svm.SVC()
grid_search_svc = GridSearchCV(clsf_svc, param_grid_svc, cv=n_fold,
                           scoring='f1',
                           return_train_score=True)

grid_search_svc.fit(X, y_num)
grid_search_svc.best_params_
# Out:
# {'C': 0.1, 'kernel': 'poly'}

# %%
# print out all params combination and its accuracy
cvres = grid_search_svc.cv_results_
print("max f1: ", cvres["mean_test_score"].max())
print("\n")
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(mean_score, params)
# Out:
# max f1:  0.8580951090638125
#
#
# 0.8166290652262271 {'C': 0.1, 'kernel': 'linear'}
# 0.8580951090638125 {'C': 0.1, 'kernel': 'poly'}
# 0.8580951090638125 {'C': 0.1, 'kernel': 'rbf'}
# 0.8580951090638125 {'C': 0.1, 'kernel': 'sigmoid'}
# 0.7339440079251991 {'C': 1, 'kernel': 'linear'}
# 0.8418396643667704 {'C': 1, 'kernel': 'poly'}
# 0.8153721820713022 {'C': 1, 'kernel': 'rbf'}
# 0.7323266745005874 {'C': 1, 'kernel': 'sigmoid'}
# 0.7593806402583831 {'C': 10, 'kernel': 'linear'}
# 0.7630232738213818 {'C': 10, 'kernel': 'poly'}
# 0.7578280309112755 {'C': 10, 'kernel': 'rbf'}
# 0.7665448471189684 {'C': 10, 'kernel': 'sigmoid'}

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression


solvers = ['newton-cg', 'lbfgs', 'liblinear']
penalty = ['l2']
c_values = [100, 10, 1.0, 0.1, 0.01]

n_fold = 5
param_grid_lr = [
    {'C': c_values,
     'solver': solvers,
     'penalty': penalty}
  ]
clsf_lr = LogisticRegression()
grid_search_lr = GridSearchCV(clsf_lr, param_grid_lr, cv=n_fold,
                           scoring='f1',
                           return_train_score=True)

grid_search_lr.fit(X, y_num)
grid_search_lr.best_params_
# Out:
# {'C': 0.01, 'penalty': 'l2', 'solver': 'newton-cg'}

# %%
# print out all params combination and its accuracy
cvres = grid_search_lr.cv_results_
print("max f1: ", cvres["mean_test_score"].max())
print("\n")
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(mean_score, params)
# Out:
# max f1:  0.8580951090638125
#
#
# 0.7864178537952797 {'C': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.7864178537952797 {'C': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.7864178537952797 {'C': 100, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.7890381287093691 {'C': 10, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.7890381287093691 {'C': 10, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.7890381287093691 {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.7931855912864012 {'C': 1.0, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.7931855912864012 {'C': 1.0, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.7894690965600055 {'C': 1.0, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.8264418209470458 {'C': 0.1, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.8264418209470458 {'C': 0.1, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.7965070946198146 {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.8580951090638125 {'C': 0.01, 'penalty': 'l2', 'solver': 'newton-cg'}
# ...

# %% [markdown]
# # Model Evaluation using Test set

# %%
from sklearn.metrics import jaccard_score
from sklearn.metrics import f1_score
from sklearn.metrics import log_loss

# %% [markdown]
# First, download and load the test set:

# %%
# !wget -O loan_test.csv https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0101ENv3/labs/loan_test.csv
# Out:
# --2021-03-01 20:57:29--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0101ENv3/labs/loan_test.csv
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.196
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3642 (3.6K) [text/csv]
# Saving to: ‘loan_test.csv’
#
# loan_test.csv       100%[===================>]   3.56K  --.-KB/s    in 0s
#
# 2021-03-01 20:57:29 (75.1 MB/s) - ‘loan_test.csv’ saved [3642/3642]

# %% [markdown]
# ### Load Test set for evaluation

# %%
test_df = pd.read_csv('loan_test.csv')
test_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           1             1     PAIDOFF       1000     30       9/8/2016
# 1           5             5     PAIDOFF        300      7       9/9/2016
# 2          21            21     PAIDOFF       1000     30      9/10/2016
# 3          24            24     PAIDOFF       1000     30      9/10/2016
# 4          35            35     PAIDOFF        800     15      9/11/2016
#
#     due_date  age             education  Gender
# 0  10/7/2016   50              Bechalor  female
# 1  9/15/2016   35       Master or Above    male
# 2  10/9/2016   43  High School or Below  female
# 3  10/9/2016   26               college    male
# 4  9/25/2016   29              Bechalor    male

# %%
test_df.shape
# Out:
# (54, 10)

# %%
test_df['due_date'] = pd.to_datetime(test_df['due_date'])
test_df['effective_date'] = pd.to_datetime(test_df['effective_date'])
test_df['dayofweek'] = test_df['effective_date'].dt.dayofweek
test_df['weekend'] = test_df['dayofweek'].apply(lambda x: 1 if (x>3)  else 0)
test_df['Gender'].replace(to_replace=['male','female'], value=[0,1],inplace=True)
Feature_test = test_df[['Principal','terms','age','Gender','weekend']]
Feature_test = pd.concat([Feature_test, pd.get_dummies(test_df['education'])], axis=1)
Feature_test.drop(['Master or Above'], axis = 1,inplace=True)
Feature_test.head()
X_test = preprocessing.StandardScaler().fit(Feature_test).transform(Feature_test)
print(X_test[0:5])
test_df['loan_status_num'] = test_df['loan_status'].apply(lambda x: 1 if (x=='PAIDOFF')  else -1)
y_test = np.asarray(test_df['loan_status_num'])
print(y_test[-5:])
# Out:
# [[ 0.49362588  0.92844966  3.05981865  1.97714211 -1.30384048  2.39791576
#   -0.79772404 -0.86135677]
#  [-3.56269116 -1.70427745  0.53336288 -0.50578054  0.76696499 -0.41702883
#   -0.79772404 -0.86135677]
#  [ 0.49362588  0.92844966  1.88080596  1.97714211  0.76696499 -0.41702883
#    1.25356634 -0.86135677]
#  [ 0.49362588  0.92844966 -0.98251057 -0.50578054  0.76696499 -0.41702883
#   -0.79772404  1.16095912]
#  [-0.66532184 -0.78854628 -0.47721942 -0.50578054  0.76696499  2.39791576
#   -0.79772404 -0.86135677]]
# [-1 -1 -1 -1 -1]

# %%
print("x_test: ", X_test.shape)
print("x_test: ", y_test.shape)
# Out:
# x_test:  (54, 8)
# x_test:  (54,)

# %% [markdown]
# ## test KNearestNeighbors

# %%
y_hat_knn = grid_search_knn.best_estimator_.predict(X_test)
js_knn = jaccard_score(y_test, y_hat_knn)
f1_knn = f1_score(y_test, y_hat_knn)
print("KNearestNeighbors Jaccard: {}, F1-score: {}".format(js_knn, f1_knn))
# Out:
# KNearestNeighbors Jaccard: 0.7, F1-score: 0.823529411764706

# %% [markdown]
# ## test decision tree

# %%
y_hat_dt = grid_search_dt.best_estimator_.predict(X_test)
js_dt = jaccard_score(y_test, y_hat_dt)
f1_dt = f1_score(y_test, y_hat_dt)
print("Decision Tree Jaccard: {}, F1-score: {}".format(js_dt, f1_dt))
# Out:
# Decision Tree Jaccard: 0.6875, F1-score: 0.8148148148148149

# %% [markdown]
# ## test svm

# %%
y_hat_svc = grid_search_svc.best_estimator_.predict(X_test)
js_svc = jaccard_score(y_test, y_hat_svc)
f1_svc = f1_score(y_test, y_hat_svc)
print("SVM Jaccard: {}, F1-score: {}".format(js_svc, f1_svc))
# Out:
# SVM Jaccard: 0.7407407407407407, F1-score: 0.851063829787234

# %% [markdown]
# ## test logistic regression

# %%
y_hat_lr = grid_search_lr.best_estimator_.predict(X_test)
y_hat_prob_lr = grid_search_lr.best_estimator_.predict_proba(X_test)
js_lr = jaccard_score(y_test, y_hat_lr)
f1_lr = f1_score(y_test, y_hat_lr)
ll_lr = log_loss(y_test, y_hat_prob_lr)
print("logistic regression Jaccard: {}, F1-score: {}, LogLoss: {}".format(js_lr, f1_lr, ll_lr))
# Out:
# logistic regression Jaccard: 0.7407407407407407, F1-score: 0.851063829787234, LogLoss: 0.5153605391282532

# %% [markdown]
# # Report
# You should be able to report the accuracy of the built model using different evaluation metrics:

# %% [markdown]
# | Algorithm          | Jaccard | F1-score | LogLoss |
# |--------------------|---------|----------|---------|
# | KNN                | 0.7       | 0.8235        | NA      |
# | Decision Tree      | 0.6875       | 0.8148        | NA      |
# | SVM                | 0.7407       | 0.8510        | NA      |
# | LogisticRegression | 0.7407       | 0.8510        | 0.5153       |

# %% [markdown]
# <h2>Want to learn more?</h2>
#
# IBM SPSS Modeler is a comprehensive analytics platform that has many machine learning algorithms. It has been designed to bring predictive intelligence to decisions made by individuals, by groups, by systems – by your enterprise as a whole. A free trial is available through this course, available here: <a href="http://cocl.us/ML0101EN-SPSSModeler">SPSS Modeler</a>
#
# Also, you can use Watson Studio to run these notebooks faster with bigger datasets. Watson Studio is IBM's leading cloud solution for data scientists, built by data scientists. With Jupyter notebooks, RStudio, Apache Spark and popular libraries pre-packaged in the cloud, Watson Studio enables data scientists to collaborate on their projects without having to install anything. Join the fast-growing community of Watson Studio users today with a free account at <a href="https://cocl.us/ML0101EN_DSX">Watson Studio</a>
#
# <h3>Thanks for completing this lesson!</h3>
#
# <h4>Author:  <a href="https://ca.linkedin.com/in/saeedaghabozorgi">Saeed Aghabozorgi</a></h4>
# <p><a href="https://ca.linkedin.com/in/saeedaghabozorgi">Saeed Aghabozorgi</a>, PhD is a Data Scientist in IBM with a track record of developing enterprise level applications that substantially increases clients’ ability to turn data into actionable knowledge. He is a researcher in data mining field and expert in developing advanced analytic methods like machine learning and statistical modelling on large datasets.</p>
#
# <hr>
#
# <p>Copyright &copy; 2018 <a href="https://cocl.us/DX0108EN_CC">Cognitive Class</a>. This notebook and its source code are released under the terms of the <a href="https://bigdatauniversity.com/mit-license/">MIT License</a>.</p>
